# %%
# %pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
#    ------------------------- ------------- 81.9/125.4 kB 770.8 kB/s eta 0:00:01
#    ---------------------------------------  122.9/125.4 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------- 125.4/125.4 kB 738.4 kB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import networkx as nx
import geopy.distance
from folium.plugins import MarkerCluster
import matplotlib.pyplot as plt

# Coordinates (No way to get the actual coordinates so I just used my intuition)
locations = [
    (-37.8136 , 144.9631),  # Melbourne
    (-37.8136, 144.9631 - 0.018),  # 1.8km to the west of Melbourne
    (-37.8136 + 0.015, 144.9631),  # 1.5km to the north of Melbourne
    (-37.8136 - 0.013, 144.9631),  # 1.3km to the south of Melbourne
    (-37.8136 - 0.013, 144.9631 + 0.030),  # 3.0km to the east of Southbank
    (-37.8136 - 0.013 - 0.017, 144.9631 + 0.030),  # 1.7km to the south of last point
    (-37.8136 - 0.013 - 0.028, 144.9631 + 0.030),  # 2.8km to the south of last point
    (-37.8136 + 0.0114, 144.9631 + 0.0144),  # 1.8km to the northeast of Melbourne
    (-37.8136 + 0.0114 + 0.0038, 144.9631 + 0.0144 + 0.0049),  # 0.6km to the northeast of last point
    
]

# Create a Folium map centered around the first location
m = folium.Map(location=locations[0], zoom_start=14)

# Add a marker cluster
marker_cluster = MarkerCluster().add_to(m)

# Add points to the map
for loc in locations:
    # folium.Marker(location=loc).add_to(marker_cluster)

    # Add edges connecting each point to another
    G = nx.Graph()  # Initialize an empty graph object
    for i in range(len(locations)):
        for j in range(i+1, len(locations)):
            G.add_edge(i, j)

    # Get the positions of the nodes
    pos = nx.spring_layout(G)

    # Draw the edges on the map
    for edge in G.edges():
        start = locations[edge[0]]
        end = locations[edge[1]]
        folium.PolyLine([start, end], color='blue').add_to(m)
    folium.Marker(location=loc).add_to(marker_cluster)

    # Add edges connecting each point to another
    for i in range(len(locations)):
        for j in range(i+1, len(locations)):
            G.add_edge(i, j)

    # Get the positions of the nodes
    pos = nx.spring_layout(G)

    # Draw the edges on the map
    for edge in G.edges():
        start = locations[edge[0]]
        end = locations[edge[1]]
        folium.PolyLine([start, end], color='blue').add_to(m)
        
    # Calculate the distance per edge
    for edge in G.edges():
        start = locations[edge[0]]
        end = locations[edge[1]]
        distance = geopy.distance.distance(start, end).km
        folium.PolyLine([start, end], color='blue', tooltip=f"Distance: {distance} km").add_to(m)

# Display the map in the Jupyter notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7528cb3e7d0fdc757148f276648880ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7528cb3e7d0fdc757148f276648880ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7528cb3e7d0fdc757148f276648880ce = L.map(
#                 &quot;map_7528cb3e7d0fdc757148f276648880ce&quot;,
#                 {
#                     center: [-37.8136, 144.9631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c87997cdf70369d4bc17c1c2af612d83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c87997cdf70369d4bc17c1c2af612d83.addTo(map_7528cb3e7d0fdc757148f276648880ce);
#
#
#             var marker_cluster_892eca298cf8dcc4f504cafa2135eee9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7c1f73511592577ce5786fcd97b526c6 = L.marker(
#                 [-37.8136, 144.9631],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_23ec44bd5ad99ed40baa967cc23701f6 = L.marker(
#                 [-37.8136, 144.9451],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_222e71e4999e606035127f587a9a9846 = L.marker(
#                 [-37.7986, 144.9631],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_279c02cbd9d3b48fb4a140f31a2da45c = L.marker(
#                 [-37.8266, 144.9631],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_1d5780fb8f1deb9cb557619f13486f49 = L.marker(
#                 [-37.8266, 144.9931],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_72a6698f17ae7119c1f9faa81da8eddf = L.marker(
#                 [-37.8436, 144.9931],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_33a6688221bf1e481648ccaeaa8e6298 = L.marker(
#                 [-37.8546, 144.9931],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_c49a9232874d17f25570d13fb9410660 = L.marker(
#                 [-37.8022, 144.9775],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             var marker_6c597607f128f6518014720cb6be38d6 = L.marker(
#                 [-37.7984, 144.98239999999998],
#                 {}
#             ).addTo(marker_cluster_892eca298cf8dcc4f504cafa2135eee9);
#
#
#             marker_cluster_892eca298cf8dcc4f504cafa2135eee9.addTo(map_7528cb3e7d0fdc757148f276648880ce);
#
#
#             var poly_line_bdd446de22c62aead1426b9dce08253a = L.polyline(
#                 [[-37.8136, 144.9631], [-37.8136, 144.9451]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7528cb3e7d0fdc757148f276648880ce);
#
#
#             var poly_line_2c82c6b807c68ecc6f6ae9cdd75de6d2 = L.polyline(
#                 [[-37.8136, 144.9631], [-37.7986, 144.9631]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7528cb3e7d0fdc757148f276648880ce);
#
#
#             var poly_line_8f2de907e919c1a44c1e3fecb66577ab = L.polyline(
#                 [[-37.8136, 144.9631], [-37.8266, 144.9631
